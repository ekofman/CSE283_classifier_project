# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # ROC Plots

# %% [markdown]
# ### ROC plot to compare the 78 genes that were optimized with the neural network

# %%
svm_top_78_NN_fpr = [0.        , 0.04347826, 0.13043478, 0.13043478, 0.17391304,       0.17391304, 0.30434783, 0.30434783, 0.39130435, 0.39130435,       0.43478261, 0.43478261, 0.47826087, 0.47826087, 0.52173913,       0.52173913, 0.73913043, 0.73913043, 0.95652174, 0.95652174,       1.        ]
svm_top_78_NN_tpr = [0.        , 0.        , 0.        , 0.11111111, 0.11111111,       0.22222222, 0.22222222, 0.33333333, 0.33333333, 0.44444444,       0.44444444, 0.55555556, 0.55555556, 0.66666667, 0.66666667,       0.77777778, 0.77777778, 0.88888889, 0.88888889, 1.        ,       1.        ]
knn_top_78_NN_fpr = [0.        , 0.03571429, 0.03571429, 0.25      , 0.25      ,       0.32142857, 0.32142857, 0.35714286, 0.35714286, 0.39285714,       0.39285714, 0.57142857, 0.57142857, 0.71428571, 0.71428571,       0.82142857, 0.82142857, 0.85714286, 1.        ]
knn_top_78_NN_tpr = [0.        , 0.        , 0.18181818, 0.18181818, 0.27272727,       0.27272727, 0.36363636, 0.36363636, 0.45454545, 0.45454545,       0.54545455, 0.54545455, 0.63636364, 0.63636364, 0.72727273,       0.72727273, 0.90909091, 0.90909091, 1.        ]
rf_top_78_NN_fpr = [0.0, 0.0, 0.09523809523809523, 0.09523809523809523, 0.2857142857142857, 0.2857142857142857, 0.42857142857142855, 0.42857142857142855, 0.5238095238095238, 0.5238095238095238, 0.6666666666666666, 0.6666666666666666, 0.7142857142857143, 0.7142857142857143, 1.0, ]
rf_top_78_NN_tpr = [0.0, 0.125, 0.125, 0.25, 0.25, 0.375, 0.375, 0.5, 0.5, 0.75, 0.75, 0.875, 0.875, 1.0, 1.0, ]
nn_top_78_NN_fpr = [0, 0.04347826, 0.04347826, 0.08695652, 0.08695652, 0.13043478, 0.13043478, 0.47826087, 0.47826087, 0.7826087, 0.7826087, 1.]
nn_top_78_NN_tpr = [0., 0.22222222, 0.33333333, 0.33333333, 0.55555556, 0.55555556, 0.77777778, 0.77777778, 0.88888889, 0.88888889, 1, 1.]

# %%
positive_rate_svm_top_78_NN = pd.DataFrame({'fpr':svm_top_78_NN_fpr, 'tpr':svm_top_78_NN_tpr, 'Classifier':'SVM'})
positive_rate_knn_top_78_NN = pd.DataFrame({'fpr':knn_top_78_NN_fpr, 'tpr':knn_top_78_NN_tpr, 'Classifier':'KNN'})
positive_rate_rf_top_78_NN = pd.DataFrame({'fpr':rf_top_78_NN_fpr, 'tpr':rf_top_78_NN_tpr, 'Classifier':'Random Forest'})
positive_rate_nn_top_78_NN = pd.DataFrame({'fpr':nn_top_78_NN_fpr, 'tpr':nn_top_78_NN_tpr, 'Classifier':'Neural Net'})
positive_rate_combined_top_78_NN = pd.concat([positive_rate_svm_top_78_NN, positive_rate_knn_top_78_NN, positive_rate_rf_top_78_NN, positive_rate_nn_top_78_NN])

# %%
sns.set(style="whitegrid")
roc = sns.lineplot(x='fpr', y='tpr', hue='Classifier', data=positive_rate_combined_top_78_NN, estimator=None)
roc.axes.set_title("Representative ROCs for 4 Classifiers on 78 Optimized Genes", fontsize=14)
roc.legend(loc='lower right')
roc.set_xlabel("False Positive Rate", fontsize=14)
roc.set_ylabel("True Positive Rate", fontsize=14)
plot_file_name="Representative ROCs for 4 Classifiers on 78 Optimized Genes.png"
roc.figure.savefig(plot_file_name, format='png', dpi=500)

# %% [markdown]
# ### ROC plot to compare the 750 breast cancer genes

# %%
svm_top_750_fpr = [0.        , 0.        , 0.17391304, 0.17391304, 0.26086957,       0.26086957, 0.39130435, 0.39130435, 0.52173913, 0.52173913,       0.56521739, 0.56521739, 0.95652174, 0.95652174, 1.        ]
svm_top_750_tpr = [0.        , 0.11111111, 0.11111111, 0.33333333, 0.33333333,       0.44444444, 0.44444444, 0.55555556, 0.55555556, 0.66666667,       0.66666667, 0.88888889, 0.88888889, 1.        , 1.        ]
knn_top_750_fpr = [0.        , 0.03571429, 0.03571429, 0.14285714, 0.14285714,       0.25      , 0.25      , 0.28571429, 0.28571429, 0.32142857,       0.32142857, 0.5       , 0.5       , 0.57142857, 0.57142857,       0.64285714, 1.        ]
knn_top_750_tpr = [0.        , 0.        , 0.09090909, 0.09090909, 0.18181818,       0.18181818, 0.27272727, 0.27272727, 0.36363636, 0.36363636,       0.45454545, 0.45454545, 0.54545455, 0.54545455, 0.63636364,       0.63636364, 1.        ]
rf_top_750_fpr = [0.0, 0.047619047619047616, 0.09523809523809523, 0.14285714285714285, 0.14285714285714285, 0.38095238095238093, 0.38095238095238093, 0.5714285714285714, 0.5714285714285714, 0.7619047619047619, 0.7619047619047619, 0.8095238095238095, 0.8571428571428571, 0.9523809523809523, 1.0, 1.0, ]
rf_top_750_tpr = [0.0, 0.125, 0.125, 0.25, 0.375, 0.375, 0.5, 0.5, 0.625, 0.625, 0.75, 0.75, 0.875, 0.875, 0.875, 1.0, ]
nn_top_750_fpr = [0.,0.04347826,0.08695652,0.08695652,0.13043478,0.13043478,0.2173913,0.217391,0.30434783,0.30434783,0.34782609,0.34782609, 0.43478261,0.43478261,0.60869565,0.60869565,0.65217391,0.65217391,1.]
nn_top_750_tpr = [0.,0.,0.,0.11111111,0.11111111,0.33333333,0.5,0.5,0.5,0.55555556,0.55555556,0.66666667,0.66666667,0.77777778,0.77777778,0.88888889,0.88888889,1.,1.]

# %%
positive_rate_svm_top_750 = pd.DataFrame({'fpr':svm_top_750_fpr, 'tpr':svm_top_750_tpr, 'Classifier':'SVM'})
positive_rate_knn_top_750 = pd.DataFrame({'fpr':knn_top_750_fpr, 'tpr':knn_top_750_tpr, 'Classifier':'KNN'})
positive_rate_rf_top_750 = pd.DataFrame({'fpr':rf_top_750_fpr, 'tpr':rf_top_750_tpr, 'Classifier':'Random Forest'})
positive_rate_nn_top_750 = pd.DataFrame({'fpr':nn_top_750_fpr, 'tpr':nn_top_750_tpr, 'Classifier':'Neural Net'})
positive_rate_combined_top_750 = pd.concat([positive_rate_svm_top_750, positive_rate_knn_top_750, positive_rate_rf_top_750, positive_rate_nn_top_750])

# %%
sns.set(style="whitegrid")
roc = sns.lineplot(x='fpr', y='tpr', hue='Classifier', data=positive_rate_combined_top_750, estimator=None)
roc.axes.set_title("Representative ROCs for 4 Classifiers on 750 Preselected Genes", fontsize=14)
roc.legend(loc='lower right')
roc.set_xlabel("False Positive Rate", fontsize=14)
roc.set_ylabel("True Positive Rate", fontsize=14)
plot_file_name="Representative ROCs for 4 Classifiers on 750 Preselected Genes.png"
roc.figure.savefig(plot_file_name, format='png', dpi=500)

# %% [markdown]
# ### ROC plot to compare the Vantveer breast cancer poor prognosis genes

# %%
svm_poor_prognosis_fpr = [0.        , 0.04347826, 0.04347826, 0.30434783, 0.30434783,       0.39130435, 0.39130435, 0.43478261, 0.43478261, 0.47826087,       0.47826087, 0.69565217, 0.69565217, 0.73913043, 0.73913043,       0.91304348, 0.91304348, 1.        ]
svm_poor_prognosis_tpr = [0.        , 0.        , 0.11111111, 0.11111111, 0.33333333,       0.33333333, 0.44444444, 0.44444444, 0.55555556, 0.55555556,       0.66666667, 0.66666667, 0.77777778, 0.77777778, 0.88888889,       0.88888889, 1.        , 1.        ]
knn_poor_prognosis_fpr = [0.        , 0.03571429, 0.10714286, 0.10714286, 0.39285714,       0.39285714, 0.46428571, 0.46428571, 0.5       , 0.5       ,       0.57142857, 0.57142857, 0.60714286, 0.60714286, 0.64285714,       1.        ]
knn_poor_prognosis_tpr = [0.        , 0.        , 0.        , 0.27272727, 0.27272727,       0.36363636, 0.36363636, 0.45454545, 0.45454545, 0.54545455,       0.54545455, 0.63636364, 0.63636364, 0.72727273, 0.72727273,       1.        ]
rf_poor_prognosis_fpr = [0.0, 0.047619047619047616, 0.19047619047619047, 0.19047619047619047, 0.38095238095238093, 0.42857142857142855, 0.6190476190476191, 0.6190476190476191, 0.7619047619047619, 0.7619047619047619, 1.0, 1.0, ]
rf_poor_prognosis_tpr = [0.0, 0.0, 0.0, 0.5, 0.5, 0.625, 0.625, 0.75, 0.75, 0.875, 0.875, 1.0, ]
nn_poor_prognosis_fpr = [0.,0.,0.,0.2173913,0.217391,0.65217391,0.65217391,0.69565217,0.69565217,0.7826087,0.7826087,1.,1.]
nn_poor_prognosis_tpr = [0.,0.22222222,0.33333333,0.5,0.5,0.5,0.55555556,0.55555556,0.77777778,0.77777778,0.88888889,0.88888889,1.]

# %%
positive_rate_svm_poor_prognosis = pd.DataFrame({'fpr':svm_poor_prognosis_fpr, 'tpr':svm_poor_prognosis_tpr, 'Classifier':'SVM'})
positive_rate_knn_poor_prognosis = pd.DataFrame({'fpr':knn_poor_prognosis_fpr, 'tpr':knn_poor_prognosis_tpr, 'Classifier':'KNN'})
positive_rate_rf_poor_prognosis = pd.DataFrame({'fpr':rf_poor_prognosis_fpr, 'tpr':rf_poor_prognosis_tpr, 'Classifier':'Random Forest'})
positive_rate_nn_poor_prognosis = pd.DataFrame({'fpr':nn_poor_prognosis_fpr, 'tpr':nn_poor_prognosis_tpr, 'Classifier':'Neural Net'})
positive_rate_combined_poor_prognosis = pd.concat([positive_rate_svm_poor_prognosis, positive_rate_knn_poor_prognosis, positive_rate_rf_poor_prognosis, positive_rate_nn_poor_prognosis])

# %%
sns.set(style="whitegrid")
roc = sns.lineplot(x='fpr', y='tpr', hue='Classifier', data=positive_rate_combined_poor_prognosis, estimator=None)
roc.axes.set_title("Representative ROCs for 4 Classifiers on Poor Prognosis Genes", fontsize=14)
roc.legend(loc='lower right')
roc.set_xlabel("False Positive Rate", fontsize=14)
roc.set_ylabel("True Positive Rate", fontsize=14)
plot_file_name="Representative ROCs for 4 Classifiers on Poor Prognosis Genes.png"
roc.figure.savefig(plot_file_name, format='png', dpi=500)

# %% [markdown]
# ### ROC plot to compare the top 100 differentially expressed genes

# %%
svm_top_100_DE_fpr = [0.        , 0.        , 0.04347826, 0.04347826, 0.08695652,       0.08695652, 0.13043478, 0.13043478, 1.        ]
svm_top_100_DE_tpr = [0.        , 0.11111111, 0.11111111, 0.77777778, 0.77777778,       0.88888889, 0.88888889, 1.        , 1.        ]
knn_top_100_DE_fpr = [0.        , 0.        , 0.        , 0.03571429, 0.03571429,       0.07142857, 0.07142857, 0.10714286, 0.10714286, 0.17857143,       1.        ]
knn_top_100_DE_tpr = [0.        , 0.09090909, 0.18181818, 0.18181818, 0.36363636,       0.36363636, 0.45454545, 0.45454545, 0.63636364, 0.63636364,       1.        ]
rf_top_100_DE_fpr = [0.0, 0.0, 0.0, 0.047619047619047616, 0.09523809523809523, 0.09523809523809523, 0.14285714285714285, 0.23809523809523808, 0.3333333333333333, 0.6190476190476191, 0.8095238095238095, 1.0]
rf_top_100_DE_tpr = [0.0, 0.125, 0.5, 0.625, 0.625, 0.75, 0.75, 0.875, 0.875, 0.875, 0.875, 1.0]
nn_top_100_DE_fpr = [0., 0.04347826, 0.04347826, 0.08695652, 0.08695652, 0.65217391, 0.65217391, 1.]
nn_top_100_DE_tpr = [0.,0.,0.44444444,0.44444444,0.88888889,0.88888889, 1.        ,1.]

# %%
positive_rate_svm_top_100_DE = pd.DataFrame({'fpr':svm_top_100_DE_fpr, 'tpr':svm_top_100_DE_tpr, 'Classifier':'SVM'})
positive_rate_knn_top_100_DE = pd.DataFrame({'fpr':knn_top_100_DE_fpr, 'tpr':knn_top_100_DE_tpr, 'Classifier':'KNN'})
positive_rate_rf_top_100_DE = pd.DataFrame({'fpr':rf_top_100_DE_fpr, 'tpr':rf_top_100_DE_tpr, 'Classifier':'Random Forest'})
positive_rate_nn_top_100_DE = pd.DataFrame({'fpr':nn_top_100_DE_fpr, 'tpr':nn_top_100_DE_tpr, 'Classifier':'Neural Net'})
positive_rate_combined_top_100_DE = pd.concat([positive_rate_svm_top_100_DE, positive_rate_knn_top_100_DE, positive_rate_rf_top_100_DE, positive_rate_nn_top_100_DE])

# %%
sns.set(style="whitegrid")
roc = sns.lineplot(x='fpr', y='tpr', hue='Classifier', data=positive_rate_combined_top_100_DE, estimator=None)
roc.axes.set_title("Representative ROCs for 4 Classifiers on Top 100 DE Genes", fontsize=14)
roc.legend(loc='lower right')
roc.set_xlabel("False Positive Rate", fontsize=14)
roc.set_ylabel("True Positive Rate", fontsize=14)
plot_file_name="Representative ROCs for 4 Classifiers on Top 100 DE Genes.png"
roc.figure.savefig(plot_file_name, format='png', dpi=500)
